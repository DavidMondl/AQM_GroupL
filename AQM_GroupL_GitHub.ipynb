# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import scipy
import seaborn as sns
import xlsxwriter

import math
from math import exp, sqrt, log

# %matplotlib inline

from scipy import stats


import statsmodels as sm
from statsmodels.regression.linear_model import OLS

# %%
import sqlite3
from sqlite3 import Error
 

def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
    finally:
        if conn:
            conn.close()
 
 
if __name__ == '__main__':
    create_connection(r"C:\Users\david\OneDrive - ZHAW\ZHAW\2nd Semester\Advanced Quantitative Methods\Paper\AQM_GroupL.db")
# Out:
# 2.6.0

# %%
conn = sqlite3.connect(r"C:\Users\david\OneDrive - ZHAW\ZHAW\2nd Semester\Advanced Quantitative Methods\Paper\AQM_GroupL.db")

print("Opened database successfully")
# Out:
# Opened database successfully

# %%
c = conn.cursor()
c.execute("SELECT * FROM bond_yields")
new_data=c.fetchall()
new_data
# Out:
# [('2010-01-31 00-00-00',
#   5.45,
#   3.468,
#   3.2,
#   3.9,
#   4.109,
#   4.391,
#   4.136,
#   3.298,
#   2.003,
#   3.588),
#  ('2010-02-28 00-00-00',
#   5.51,
#   3.423,
#   3.107,
#   4.032,
#   4.007,
#   4.474,
#   3.876,
#   3.178,
#   1.916,
#   3.619),
#  ('2010-03-31 00-00-00',
#   5.782,
#   3.439,
#   3.102,
#   3.945,
#   3.872,
#   4.234,
#   3.819,
#   3.177,
#   1.892,
#   3.833),
#  ('2010-04-30 00-00-00',
#   5.715,
#   3.3,
#   2.965,
#   3.914,
#   3.984,
#   5.092,
#   4.041,
#   2.976,
#   1.831,
#   3.659),
#  ('2010-05-31 00-00-00',
#   5.372,
#   2.916,
#   2.653,
#   3.578,
#   4.155,
#   4.866,
#   4.298,
#   2.64,
#   1.57,
#   3.303),
#  ('2010-06-30 00-00-00',
#   5.113,
#   3.055,
#   2.552,
#   3.365,
#   4.092,
#   5.984,
#   4.574,
#   2.679,
#   1.523,
#   2.935),
#  ('2010-07-31 00-00-00',
#   5.215,
#   2.956,
#   2.672,
#   3.322,
#   3.953,
#   5.305,
#   4.231,
#   2.758,
#   1.481,
#   2.905),
#  ('2010-08-31 00-00-00',
#   4.778,
# ...

# %%
new_data=pd.DataFrame(new_data,columns=['Date','Germany','Italy','France','Spain','United_States','Great_Britain','Sweden','Switzerland','Portugal','Australia'])
new_data.head()
# Out:
#                   Date  Germany  Italy  France  Spain  United_States  \
# 0  2010-01-31 00-00-00    5.450  3.468   3.200  3.900          4.109
# 1  2010-02-28 00-00-00    5.510  3.423   3.107  4.032          4.007
# 2  2010-03-31 00-00-00    5.782  3.439   3.102  3.945          3.872
# 3  2010-04-30 00-00-00    5.715  3.300   2.965  3.914          3.984
# 4  2010-05-31 00-00-00    5.372  2.916   2.653  3.578          4.155
#
#    Great_Britain  Sweden  Switzerland  Portugal  Australia
# 0          4.391   4.136        3.298     2.003      3.588
# 1          4.474   3.876        3.178     1.916      3.619
# 2          4.234   3.819        3.177     1.892      3.833
# 3          5.092   4.041        2.976     1.831      3.659
# 4          4.866   4.298        2.640     1.570      3.303
